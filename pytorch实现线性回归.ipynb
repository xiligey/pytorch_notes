// %%
import torch
from matplotlib import pyplot as plt
import numpy as np
import random

// %%
torch
// Out:
// <module 'torch' from '/Users/chenxilin/opt/anaconda3/lib/python3.8/site-packages/torch/__init__.py'>
